# %%
# !install ttf-mscorefonts-installer
# Out:
# usage: install [-bCcpSsUv] [-f flags] [-g group] [-m mode] [-o owner]
#                [-M log] [-D dest] [-h hash] [-T tags]
#                [-B suffix] [-l linkflags] [-N dbdir]
#                file1 file2
#        install [-bCcpSsUv] [-f flags] [-g group] [-m mode] [-o owner]
#                [-M log] [-D dest] [-h hash] [-T tags]
#                [-B suffix] [-l linkflags] [-N dbdir]
#                file1 ... fileN directory
#        install -dU [-vU] [-g group] [-m mode] [-N dbdir] [-o owner]
#                [-M log] [-D dest] [-h hash] [-T tags]
#                directory ...

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in ./Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from opencv-python) (2.1.0)
# Downloading opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 2.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont

# Define the path to your map image
image_path = "map.jpg"

# Load the image using PIL
image = Image.open(image_path)
draw = ImageDraw.Draw(image)

# Define the highlight color (pink)
highlight_color = (255, 182, 193)
text_color = (0, 0, 0)  # Black text for labels

# Approximate locations of specified countries on the map
country_positions = {
    "France": (990, 425),
    "Denmark": (1020, 360),
    "Norway": (640, 150),
    "Chile": (550, 940),
    "Mexico": (380, 580),
    "Senegal": (520, 350),
    "Bulgaria": (660, 270),
    "Togo": (540, 370),
    "Iceland": (580, 130),
    "Costa Rica": (480, 640),
    "Luxembourg": (610, 245),
}

# Load a font (default system font if not found)
try:
    font = ImageFont.truetype("arial.ttf", 50)
except IOError:
    font = ImageFont.load_default()

# Draw circles and add country names
for country, (x, y) in country_positions.items():
    draw.ellipse((x-10, y-10, x+10, y+10), fill=highlight_color)
    draw.text((x + 12, y - 8), country, fill=text_color, font=font)

# Display the updated image
plt.figure(figsize=(10, 6))
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont

# Define the path to your map image
image_path = "/Users/olga/Downloads/map.jpg"

# Load the image using PIL
image = Image.open(image_path)
draw = ImageDraw.Draw(image)

# Define the highlight color (pink)
highlight_color = (255, 100, 100)
text_color = (0, 0, 0)  # Black text for labels

# Approximate locations of specified countries on the map
country_positions = {
    "France": (990, 430),
    "Denmark": (1010, 360),
    "Norway": (1020, 320),
    "Chile": (550, 940),
    "Mexico": (380, 580),
    "Senegal": (890, 650),
    "Bulgaria": (1120, 460),
    "Togo": (990, 680),
    "Iceland": (860, 290),
    "Costa Rica": (480, 650),
    "Luxembourg": (1020, 410),
}

# Load a font (default system font if not found)
try:
    font_path = "/usr/share/fonts/truetype/msttcorefonts/Arial.ttf"
    font = ImageFont.truetype(font_path, 30)
except IOError:
    font = ImageFont.load_default()

# Draw circles and add country names
for country, (x, y) in country_positions.items():
    draw.ellipse((x-10, y-10, x+10, y+10), fill=highlight_color)
    draw.text((x + 22, y - 8), country, fill=text_color, font=font)

# Display the updated image
plt.figure(figsize=(10, 6))
plt.imshow(image)
plt.axis("off")
plt.show()
